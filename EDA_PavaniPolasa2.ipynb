# %% [markdown]
# <a href="https://colab.research.google.com/github/1111-2002/majorproject-collab-notebook-rinex/blob/main/EDA_PavaniPolasa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/train.csv.zip')
df
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 0      ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1      ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2      ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3      ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4      ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
# ...           ...                  ...                  ...        ...
# 18829  ANSL_51738  2017-01-26 00:00:00  2018-03-09 15:35:00        2.0
# 18830  ANSL_59900  2016-06-18 00:00:00  2017-07-09 08:37:00        NaN
# 18831  ANSL_53210  2010-07-21 00:00:00  2018-08-22 14:27:00        0.0
# 18832  ANSL_63468  2017-05-12 00:00:00  2018-02-08 14:05:00        0.0
# 18833  ANSL_73558  2011-12-13 00:00:00  2018-10-26 14:18:00        0.0
#
#          color_type  length(m)  height(cm)  X1  X2  breed_category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18834 entries, 0 to 18833
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pet_id          18834 non-null  object
#  1   issue_date      18834 non-null  object
#  2   listing_date    18834 non-null  object
#  3   condition       17357 non-null  float64
#  4   color_type      18834 non-null  object
#  5   length(m)       18834 non-null  float64
#  6   height(cm)      18834 non-null  float64
#  7   X1              18834 non-null  int64
#  8   X2              18834 non-null  int64
#  9   breed_category  18834 non-null  float64
#  10  pet_category    18834 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (18834, 11)

# %%
df.size
# Out:
# 207174

# %%
df.columns
# Out:
# Index(['pet_id', 'issue_date', 'listing_date', 'condition', 'color_type',
#        'length(m)', 'height(cm)', 'X1', 'X2', 'breed_category',
#        'pet_category'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# pet_id               0
# issue_date           0
# listing_date         0
# condition         1477
# color_type           0
# length(m)            0
# height(cm)           0
# X1                   0
# X2                   0
# breed_category       0
# pet_category         0
# dtype: int64

# %%
df.nunique()
# Out:
# pet_id            18834
# issue_date         3907
# listing_date      17209
# condition             3
# color_type           56
# length(m)           101
# height(cm)         4425
# X1                   20
# X2                   10
# breed_category        3
# pet_category          4
# dtype: int64

# %%
df.head()
# Out:
#        pet_id           issue_date         listing_date  condition  \
# 0  ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1  ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2  ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3  ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4  ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
#
#     color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0  Brown Tabby       0.80        7.78  13   9             0.0             1
# 1        White       0.72       14.19  13   9             0.0             2
# 2        Brown       0.15       40.90  15   4             2.0             4
# 3        White       0.62       17.82   0   1             0.0             2
# 4        Black       0.50       11.06  18   4             0.0             1

# %%
df.tail()
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 18829  ANSL_51738  2017-01-26 00:00:00  2018-03-09 15:35:00        2.0
# 18830  ANSL_59900  2016-06-18 00:00:00  2017-07-09 08:37:00        NaN
# 18831  ANSL_53210  2010-07-21 00:00:00  2018-08-22 14:27:00        0.0
# 18832  ANSL_63468  2017-05-12 00:00:00  2018-02-08 14:05:00        0.0
# 18833  ANSL_73558  2011-12-13 00:00:00  2018-10-26 14:18:00        0.0
#
#          color_type  length(m)  height(cm)  X1  X2  breed_category  \
# 18829      Tricolor       0.44       27.36   0   1             0.0
# 18830         Brown       0.73       14.25  15   4             2.0
# 18831  Calico Point       0.99       28.13  13   9             1.0
# 18832           Tan       0.55       44.82  13   9             1.0
# 18833         Brown       0.86       37.40   0   1             1.0
#
#        pet_category
# 18829             2
# 18830             4
# 18831             1
# 18832             2
# 18833             2

# %%
df['pet_category'].value_counts().plot(kind='bar')

# %%
import seaborn as sns
sns.distplot(df['height(cm)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
sns.barplot(x=df['pet_category'],y=df['breed_category'])
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text major ticklabel objects>)

# %%
sns.heatmap(df.corr())

# %%
plt.figure(figsize=(9,5))
df['X2'].value_counts().plot(kind='bar')

# %%
sns.pairplot(df)

# %%
df_numeric=df.select_dtypes(include=['float64','int64'])
df_numeric
# Out:
#        condition  length(m)  height(cm)  X1  X2  breed_category  pet_category
# 0            2.0       0.80        7.78  13   9             0.0             1
# 1            1.0       0.72       14.19  13   9             0.0             2
# 2            NaN       0.15       40.90  15   4             2.0             4
# 3            1.0       0.62       17.82   0   1             0.0             2
# 4            2.0       0.50       11.06  18   4             0.0             1
# ...          ...        ...         ...  ..  ..             ...           ...
# 18829        2.0       0.44       27.36   0   1             0.0             2
# 18830        NaN       0.73       14.25  15   4             2.0             4
# 18831        0.0       0.99       28.13  13   9             1.0             1
# 18832        0.0       0.55       44.82  13   9             1.0             2
# 18833        0.0       0.86       37.40   0   1             1.0             2
#
# [18834 rows x 7 columns]

# %%
df_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18834 entries, 0 to 18833
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   condition       17357 non-null  float64
#  1   length(m)       18834 non-null  float64
#  2   height(cm)      18834 non-null  float64
#  3   X1              18834 non-null  int64
#  4   X2              18834 non-null  int64
#  5   breed_category  18834 non-null  float64
#  6   pet_category    18834 non-null  int64
# dtypes: float64(4), int64(3)
# memory usage: 1.0 MB

# %%
x=df_numeric.iloc[:,0:3].values
x
# Out:
# array([[ 2.  ,  0.8 ,  7.78],
#        [ 1.  ,  0.72, 14.19],
#        [  nan,  0.15, 40.9 ],
#        ...,
#        [ 0.  ,  0.99, 28.13],
#        [ 0.  ,  0.55, 44.82],
#        [ 0.  ,  0.86, 37.4 ]])

# %%
y=df_numeric.iloc[:,3].values
y
# Out:
# array([13, 13, 15, ..., 13, 13,  0])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
print(x.shape)
print(x_test.shape)
print(x_train.shape)
# Out:
# (18834, 3)
# (4709, 3)
# (14125, 3)

# %%
print(y.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (18834,)
# (4709,)
# (14125,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
